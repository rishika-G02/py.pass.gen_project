# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika-G02/py.pass.gen_project/blob/main/rishika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

def generate_password(length=12, use_digits=True, use_symbols=True, use_upper=True, use_lower=True):
    characters = ""

    if use_lower:
        characters += string.ascii_lowercase
    if use_upper:
        characters += string.ascii_uppercase
    if use_digits:
        characters += string.digits
    if use_symbols:
        characters += "!@#$%^&*()-_=+[]{};:,./<>?"

    if characters == "":
        return "Error: No character set selected!"

    password = "".join(random.choice(characters) for _ in range(length))
    return password

# -------------------------
# Input values for Colab
length = 16
use_digits = True
use_symbols = True
use_upper = True
use_lower = True

# -------------------------
password = generate_password(length, use_digits, use_symbols, use_upper, use_lower)
print("Generated Password:", password)
# Out:
# Generated Password: QcJS1s)D8]I9Xpc&
